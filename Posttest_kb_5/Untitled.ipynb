# %% [markdown]
# POSTTEST 5
#
# Nama : Asrina Nur Syahbani
# NIM  : 2009106131

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('fruits.csv')
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype   mass  width  height  color_score
# 0            1      apple  granny_smith  192.0    8.4     7.3         0.55
# 1            1      apple  granny_smith  180.0    8.0     6.8         0.59
# 2            1      apple  granny_smith  176.0    7.4     7.2         0.60
# 3            2   mandarin      mandarin   86.0    6.2     4.7         0.80
# 4            2   mandarin      mandarin   84.0    6.0     4.6         0.79

# %% [markdown]
# INFORMASI

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    60 non-null     int64
#  1   fruit_name     60 non-null     object
#  2   fruit_subtype  60 non-null     object
#  3   mass           51 non-null     float64
#  4   width          60 non-null     float64
#  5   height         51 non-null     float64
#  6   color_score    60 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.4+ KB

# %% [markdown]
# DESKRIPSI

# %%
df.describe()
# Out:
#        fruit_label          mass      width     height  color_score
# count    60.000000     51.000000  60.000000  51.000000    60.000000
# mean      2.916667    762.039216   7.048333   7.711765     0.748167
# std       1.139308   4178.009928   0.829844   1.453224     0.070555
# min       1.000000     76.000000   5.800000   4.000000     0.550000
# 25%       2.000000    131.000000   6.275000   7.250000     0.717500
# 50%       3.000000    158.000000   7.200000   7.700000     0.730000
# 75%       4.000000    183.000000   7.325000   8.300000     0.790000
# max       4.000000  30000.000000   9.600000  10.500000     0.930000

# %%
df.isna().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             9
# width            0
# height           9
# color_score      0
# dtype: int64

# %%
data = df[['fruit_label','mass','width', 'height','color_score']]

# %%
data_train, data_test = train_test_split(data,test_size=2)

# %%
len(data)
# Out:
# 60

# %% [markdown]
# EDA

# %%
plt.figure(figsize=(5,10))
sns.pairplot(df,hue="width")
plt.show()

# %% [markdown]
# KLASIFIKASI DATA

# %% [markdown]
# SPLIT DATA

# %%
data = df[['fruit_label','mass','width', 'height','color_score' ]]
label = df[['width']]

data_train, data_test, label_train, label_test = train_test_split(data, label, test_size=.2)

# %% [markdown]
# KNN

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(data_train,label_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 2
#       1 knn = KNeighborsClassifier(n_neighbors=5)
# ----> 2 knn.fit(data_train,label_train)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\neighbors\_classification.py:207, in KNeighborsClassifier.fit(self, X, y)
#     188 """Fit the k-nearest neighbors classifier from the training dataset.
#     189
#     190 Parameters
#    (...)
#     203     The fitted k-nearest neighbors classifier.
#     204 """
#     205 self.weights = _check_weights(self.weights)
# --> 207 return self._fit(X, y)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\neighbors\_base.py:407, in NeighborsBase._fit(self, X, y)
#     405 if self._get_tags()["requires_y"]:
#     406     if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# ...

# %%
classifier = GaussianNB()

# %%
classifier.fit(data_train, label_train)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 classifier.fit(data_train, label_train)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\naive_bayes.py:243, in GaussianNB.fit(self, X, y, sample_weight)
#     220 """Fit Gaussian Naive Bayes according to X, y.
#     221
#     222 Parameters
#    (...)
#     240     Returns the instance itself.
#     241 """
#     242 y = self._validate_data(y=y)
# --> 243 return self._partial_fit(
#     244     X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     245 )
#
# ...

# %%
predicted_label = classifier.predict(data_test)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 predicted_label = classifier.predict(data_test)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\naive_bayes.py:80, in _BaseNB.predict(self, X)
#      66 """
#      67 Perform classification on an array of test vectors X.
#      68
#    (...)
#      77     Predicted target values for X.
#      78 """
#      79 check_is_fitted(self)
# ---> 80 X = self._check_X(X)
#      81 jll = self._joint_log_likelihood(X)
#      82 return self.classes_[np.argmax(jll, axis=1)]
#
# ...

# %%
akurasi = accuracy_score(label_test, predict_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 akurasi = accuracy_score(label_test, predict_label)
#
# NameError: name 'predict_label' is not defined

# %%
print(f'hasil prediksi : {predicted_label}',
      f'label : {label_test}',
      f'akurasi : {akurasi}',
      sep='\n'
     )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 print(f'hasil prediksi : {predicted_label}',
#       2       f'label : {label_test}',
#       3       f'akurasi : {akurasi}',
#       4       sep='\n'
#       5      )
#
# NameError: name 'predicted_label' is not defined

# %%
dt = DecisionTreeClassifier()
dt.fit(data_train, label_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [18], line 2
#       1 dt = DecisionTreeClassifier()
# ----> 2 dt.fit(data_train, label_train)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# ...

# %%
print("Akurasi algoritma Decision Tree dengan default paramater :", {akurasi})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 print("Akurasi algoritma Decision Tree dengan default paramater :", {akurasi})
#
# NameError: name 'akurasi' is not defined

# %%
gnb  = GaussianNB()
gnb.fit(data_train,label_train)
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [21], line 2
#       1 gnb  = GaussianNB()
# ----> 2 gnb.fit(data_train,label_train)
#
# File c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\naive_bayes.py:243, in GaussianNB.fit(self, X, y, sample_weight)
#     220 """Fit Gaussian Naive Bayes according to X, y.
#     221
#     222 Parameters
#    (...)
#     240     Returns the instance itself.
#     241 """
#     242 y = self._validate_data(y=y)
# --> 243 return self._partial_fit(
# ...

# %%
data, label = datasets.load_diabetes(return_X_y=True)
data = data[:, np.newaxis, 2]

data_train2 = data[:-50]
data_test2 = data[-50:]

label_train2 = label[:-50]
label_test2 = label[-50:]

# %%
reg = LinearRegression()
reg.fit(data_train2,label_train2)
# Out:
# LinearRegression()

# %%
predict_label = reg.predict(data_test2)

plt.figure(figsize=(10,5))

plt.scatter(data_test2, label_test2, color="green",label="Nilai konkret")
plt.plot(data_test2, predict_label, color="yellow",label="Nilai estimasi")
plt.title('Linear Regression')
plt.xlabel('Data test')
plt.ylabel('Label')
plt.legend(loc ='lower right')
plt.show()
